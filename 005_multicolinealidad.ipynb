# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# !ls
# Out:
# 001_repaso_python.ipynb     Salary_Data.csv.xls
# 002_repaso_algoritmos.ipynb bloodpress.txt
# 003_kNN.ipynb               iris_ds.csv
# 004_codificadores.ipynb     test.csv
# 005_multicolinealidad.ipynb train.csv
# README.md                   winequaality-red.csv

# %%
df = pd.read_csv('Salary_Data.csv.xls')
df.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                  YearsExperience       Age    Salary
# YearsExperience         1.000000  0.987258  0.978242
# Age                     0.987258  1.000000  0.974530
# Salary                  0.978242  0.974530  1.000000

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de correlación')
plt.show()

# %%
df = pd.read_csv('./bloodpress.txt', sep='\t')
df.head()
# Out:
#    Pt   BP  Age  Weight   BSA  Dur  Pulse  Stress
# 0   1  105   47    85.4  1.75  5.1     63      33
# 1   2  115   49    94.2  2.10  3.8     70      14
# 2   3  116   49    95.3  1.98  8.2     72      10
# 3   4  117   50    94.7  2.01  5.8     73      99
# 4   5  112   51    89.4  1.89  7.0     72      95

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#               Pt        BP       Age    Weight       BSA       Dur     Pulse  \
# Pt      1.000000  0.031135  0.042694  0.024857 -0.031288  0.176246  0.112285
# BP      0.031135  1.000000  0.659093  0.950068  0.865879  0.292834  0.721413
# Age     0.042694  0.659093  1.000000  0.407349  0.378455  0.343792  0.618764
# Weight  0.024857  0.950068  0.407349  1.000000  0.875305  0.200650  0.659340
# BSA    -0.031288  0.865879  0.378455  0.875305  1.000000  0.130540  0.464819
# Dur     0.176246  0.292834  0.343792  0.200650  0.130540  1.000000  0.401514
# Pulse   0.112285  0.721413  0.618764  0.659340  0.464819  0.401514  1.000000
# Stress  0.343152  0.163901  0.368224  0.034355  0.018446  0.311640  0.506310
#
#           Stress
# Pt      0.343152
# BP      0.163901
# Age     0.368224
# Weight  0.034355
# BSA     0.018446
# Dur     0.311640
# Pulse   0.506310
# Stress  1.000000

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de correlación')
plt.show()

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /Users/pedroromeromartinez/anaconda3/envs/regresion/lib/python3.11/site-packages (from plotly) (24.1)
# Using cached plotly-5.24.1-py3-none-any.whl (19.1 MB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.24.1 tenacity-9.0.0

# %%
import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'browser'
fig = px.scatter_matrix(df, dimensions=df.columns)
fig.show()
